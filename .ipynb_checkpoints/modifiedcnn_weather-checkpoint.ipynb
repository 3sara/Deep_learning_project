# %%
# !module load cuda

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision.io import read_image
import torchvision.transforms as T

import torch.nn as nn
import torch.nn.functional as F

from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

from jupyterplot import ProgressPlot
from tqdm import tqdm, trange

# %%
class WeatherDataset(Dataset):
    def __init__(self, weather_data = 'data/big_arpafvg.csv', img_dir = 'data/images_enhanced'):
        initial_data=pd.read_csv(weather_data)
        initial_data = initial_data.drop(columns=['Temp. min gradi C','Temp. med gradi C','Temp. max gradi C','Vento med km/h','Dir. V. max gradi N'])
        #normalize the data
        for col in initial_data.columns:
            if col != 'giorno' and col != 'mese' and col != 'anno':
                initial_data[col] = (initial_data[col] - initial_data[col].mean()) / initial_data[col].std()
        self.weather_data = initial_data
        self.img_dir = img_dir

    def __getitem__(self, date):
        #get day month year from date in format dd-mm-yyyy
        day, month, year = date.split('_')
        #get from weather data the row with the same date
        weather_data = self.weather_data[(self.weather_data['giorno'] == int(day)) & (self.weather_data['mese'] == int(month)) & (self.weather_data['anno'] == int(year))]
        weather_data = torch.tensor(weather_data.values[0])

        image = os.path.join(self.img_dir, str(date) + '.jpg')  
        image = read_image(image)   
        return [image, weather_data]
    
    def __len__(self):
        return len(self.weather_data)

# %%
dataset = WeatherDataset()

# %%
#generate a list of strings dd-mm-yyyy from 01-06-2023 to 15-6-2024
from datetime import datetime, timedelta
start_date = datetime.strptime("01_01_2022", "%d_%m_%Y")
end_date = datetime.strptime("15_06_2024", "%d_%m_%Y")
date_generated = [start_date + timedelta(days=x) for x in range(0, (end_date-start_date).days)]
#transform the list of datetime objects in a list of strings in format dd-mm-yyyy
date_generated = [date.strftime("%d_%m_%Y") for date in date_generated]

# %%
train_len = int(0.8 * len(date_generated))
test_len = len(date_generated) - train_len
#split the dataset: date_trainset contains the first 80% of the dates, date_testset contains the remaining 20%
date_trainset = date_generated[:train_len]
date_testset = date_generated[train_len:]

# %%
(image, weather_data) = dataset[date_generated[np.random.randint(low = 0, high = len(dataset))]]
#print(weather_data)
#print(image)

# %%
class DeepWeather(nn.Module):
    def __init__(self):
        super(DeepWeather, self).__init__()

        self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 8, kernel_size = (3, 3), stride = 1)
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(p = 0.3)
        self.bn1 = nn.BatchNorm2d(8)
        self.conv2 = nn.Conv2d(in_channels = 8, out_channels = 16, kernel_size = (3, 3), stride = 1)
        self.bn2 = nn.BatchNorm2d(16)
        self.conv3 = nn.Conv2d(in_channels = 16, out_channels = 32, kernel_size = (3, 3), stride = 1)
        self.bn3 = nn.BatchNorm2d(32)
        self.conv4 = nn.Conv2d(in_channels = 32, out_channels = 64, kernel_size = (3, 3), stride = 1)
        self.bn4 = nn.BatchNorm2d(64)
        self.conv5 = nn.Conv2d(in_channels = 64, out_channels = 128, kernel_size = (3, 3), stride = 1)
        self.bn5 = nn.BatchNorm2d(128)
        self.conv6 = nn.Conv2d(in_channels = 128, out_channels = 256, kernel_size = (3, 3), stride = 1)
        self.bn6 = nn.BatchNorm2d(256)
        self.fc1 = nn.Linear(9226, 1024)
        self.fc2 = nn.Linear(1024, 128)
        self.fc3 = nn.Linear(128, 1)

    def forward(self, inputs):
        x1, x2 = inputs[0], inputs[1]
        

        x1 = self.bn1(self.dropout(self.pool(F.leaky_relu(self.conv1(x1)))))
        x1 = self.bn2(self.dropout(self.pool(F.leaky_relu(self.conv2(x1)))))
        x1 = self.bn3(self.dropout(self.pool(F.leaky_relu(self.conv3(x1)))))
        x1 = self.bn4(self.dropout(self.pool(F.leaky_relu(self.conv4(x1)))))
        x1 = self.bn5(self.dropout(self.pool(F.leaky_relu(self.conv5(x1)))))
        x1 = self.bn6(self.dropout(self.pool(F.leaky_relu(self.conv6(x1)))))
        x1 = torch.flatten(x1, start_dim = 1)

        x = torch.cat((x1, x2), dim = 1)
        x = F.leaky_relu(self.fc1(x))
        x = F.leaky_relu(self.fc2(x))
        x = self.fc3(x)

        return x

# %%
def train(model, dataset, batch_size,date_trainloader, date_testloader, criterion, optimizer, epochs, first_time = True, num_saved_epochs = 0):
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    model.to(device)
    train_loss_epochs = []
    test_loss_epochs = []
    bar = trange(epochs, desc=f"Epoch ?/?, Train Loss: ?, Test Loss: ?")
    for epoch in bar:
        model.train()
        train_losses = []
        for date_inputs in date_trainloader:
            for date_idx in range(batch_size):
                #print(f'date inputs{date_inputs[date_idx]} and this is the index {date_idx}')
                
                date_input=date_inputs[date_idx]
            

                inputs = dataset[date_input]
                #convert to right type, size and load to device
                inputs = [inputs[0].float().unsqueeze(0).to(device), inputs[1].float().unsqueeze(0).to(device)]

                #increment of 1 day the date_inputs
                date_next_day = date_input.split('_')
                date_next_day = datetime(int(date_next_day[2]), int(date_next_day[1]), int(date_next_day[0])) + timedelta(days = 1)
                date_next_day = date_next_day.strftime("%d_%m_%Y")
                target=dataset[date_next_day][1][3].float().to(device)
                outputs = model(inputs)
                loss = criterion(outputs.squeeze(), target)
                train_losses.append(loss.item())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
        train_loss_epochs.append(np.mean(train_losses))
        model.eval()
        test_losses = []
        for date_inputs in date_testloader:
            for date_idx in range(batch_size):
                date_input=date_inputs[date_idx]

                inputs = dataset[date_input]
                #convert to right type, size and load to device
                inputs = [inputs[0].float().unsqueeze(0).to(device), inputs[1].float().unsqueeze(0).to(device)]

                #increment of 1 day the date_inputs
                date_next_day = date_input.split('_')
                date_next_day = datetime(int(date_next_day[2]), int(date_next_day[1]), int(date_next_day[0])) + timedelta(days = 1)
                date_next_day = date_next_day.strftime("%d_%m_%Y")
                target=dataset[date_next_day][1][3].float().to(device)
                outputs = model(inputs)
                loss = criterion(outputs.squeeze(), target)
                test_losses.append(loss.item())
                
        test_loss_epochs.append(np.mean(test_losses))
        bar.set_description(f"Epoch {epoch + 1}/{epochs}, Train Loss: {np.mean(train_losses)}, Test Loss: {np.mean(test_losses)}")
        #if first_time:
            #torch.save(model.state_dict(), f"deepweather_epoch{num_saved_epochs + epoch + 1}.pth")

    return train_loss_epochs, test_loss_epochs

# %%
#Uncomment the lines below if you want to train/load a pretrained model
#num_saved_epochs = 50
#model = model.load_state_dict(torch.load(f'weights/epoch_{num_saved_epochs}'))

#Comment the (ONE) line below if you want to train/load a pretrained model.
#!mkdir weights
model = DeepWeather()
batch_size = 4

date_trainloader = DataLoader(date_trainset, batch_size = batch_size, shuffle = False)

date_testloader = DataLoader(date_testset, batch_size = batch_size, shuffle = False)

criterion = torch.nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 10e-6, momentum = 0)

# %%
train_losses, test_losses = train(model, dataset, batch_size, date_trainloader, date_testloader, criterion, optimizer, epochs = 50, first_time = True, num_saved_epochs = 0)
# Out:
# Epoch ?/?, Train Loss: ?, Test Loss: ?:   0%|                                                    | 0/50 [00:00<?, ?it/s]/orfeo/cephfs/home/dssc/scarpene/jupyter/lib64/python3.9/site-packages/torch/nn/modules/conv.py:456: UserWarning: Attempt to open cnn_infer failed: handle=0 error: libcudnn_cnn_infer.so.8: cannot open shared object file: No such file or directory (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:81.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch 50/50, Train Loss: 1.0774527378908771, Test Loss: 0.9985059824075304: 100%|███████| 50/50 [05:01<00:00,  6.04s/it]

# %%
epochs = [epoch for epoch in range(50)]
plt.plot(epochs, train_losses, label = 'Training Loss')
plt.plot(epochs, test_losses, label = 'Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
def predict(model, date):
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

    inputs = dataset[date]
    inputs = [inputs[0].float().unsqueeze(0).to(device), inputs[1].float().unsqueeze(0).to(device)]

    outputs = model(inputs)    
    
    return outputs

# %%
print(predict(model, '31_12_2023'))
print(dataset['31_12_2023'][1][3])
# Out:
# tensor([[0.4188]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor(-0.1916, dtype=torch.float64)

# %%
for date in date_testset:
    predicted_rain = predict(model, date)
    #non normalized results
    predicted_rain = predicted_rain 
    print(f"Predicted rain normalized for {date} is {predicted_rain}")
    #while real rain is
    print(f"Real rain normalized  for {date} is {dataset[date][1][3]}")
# Out:
# Predicted rain normalized for 18_12_2023 is tensor([[0.4165]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 18_12_2023 is -0.32236044818546217
# Predicted rain normalized for 19_12_2023 is tensor([[0.4166]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 19_12_2023 is -0.32236044818546217
# Predicted rain normalized for 20_12_2023 is tensor([[0.4184]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 20_12_2023 is -0.32236044818546217
# Predicted rain normalized for 21_12_2023 is tensor([[0.4168]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 21_12_2023 is -0.32236044818546217
# Predicted rain normalized for 22_12_2023 is tensor([[0.4175]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 22_12_2023 is -0.32236044818546217
# Predicted rain normalized for 23_12_2023 is tensor([[0.4175]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 23_12_2023 is -0.32236044818546217
# Predicted rain normalized for 24_12_2023 is tensor([[0.4180]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 24_12_2023 is -0.32236044818546217
# Predicted rain normalized for 25_12_2023 is tensor([[0.4178]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 25_12_2023 is -0.32236044818546217
# Predicted rain normalized for 26_12_2023 is tensor([[0.4187]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 26_12_2023 is -0.32236044818546217
# Predicted rain normalized for 27_12_2023 is tensor([[0.4187]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 27_12_2023 is -0.32236044818546217
# Predicted rain normalized for 28_12_2023 is tensor([[0.4187]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 28_12_2023 is -0.32236044818546217
# Predicted rain normalized for 29_12_2023 is tensor([[0.4188]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 29_12_2023 is -0.32236044818546217
# Predicted rain normalized for 30_12_2023 is tensor([[0.4189]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 30_12_2023 is -0.29620301709202873
# Predicted rain normalized for 31_12_2023 is tensor([[0.4188]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 31_12_2023 is -0.19157329271829518
# Predicted rain normalized for 01_01_2024 is tensor([[0.4155]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 01_01_2024 is -0.08694356834456159
# Predicted rain normalized for 02_01_2024 is tensor([[0.4157]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 02_01_2024 is -0.2046520082650119
# Predicted rain normalized for 03_01_2024 is tensor([[0.4159]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 03_01_2024 is -0.32236044818546217
# Predicted rain normalized for 04_01_2024 is tensor([[0.4159]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 04_01_2024 is -0.32236044818546217
# Predicted rain normalized for 05_01_2024 is tensor([[0.4150]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 05_01_2024 is 0.030764871575888707
# Predicted rain normalized for 06_01_2024 is tensor([[0.4154]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 06_01_2024 is 2.633429265372512
# Predicted rain normalized for 07_01_2024 is tensor([[0.4160]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 07_01_2024 is -0.2046520082650119
# Predicted rain normalized for 08_01_2024 is tensor([[0.4157]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 08_01_2024 is -0.29620301709202873
# Predicted rain normalized for 09_01_2024 is tensor([[0.4136]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 09_01_2024 is -0.32236044818546217
# Predicted rain normalized for 10_01_2024 is tensor([[0.4152]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 10_01_2024 is -0.32236044818546217
# Predicted rain normalized for 11_01_2024 is tensor([[0.4143]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 11_01_2024 is -0.32236044818546217
# Predicted rain normalized for 12_01_2024 is tensor([[0.4150]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 12_01_2024 is -0.32236044818546217
# Predicted rain normalized for 13_01_2024 is tensor([[0.4141]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 13_01_2024 is -0.32236044818546217
# Predicted rain normalized for 14_01_2024 is tensor([[0.4164]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 14_01_2024 is -0.1654158616248618
# Predicted rain normalized for 15_01_2024 is tensor([[0.4165]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 15_01_2024 is -0.3092817326387455
# Predicted rain normalized for 16_01_2024 is tensor([[0.4152]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 16_01_2024 is -0.3092817326387455
# Predicted rain normalized for 17_01_2024 is tensor([[0.4163]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 17_01_2024 is 2.071044496863694
# Predicted rain normalized for 18_01_2024 is tensor([[0.4164]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 18_01_2024 is 1.1293769775000913
# Predicted rain normalized for 19_01_2024 is tensor([[0.4159]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 19_01_2024 is 0.5669922089912733
# Predicted rain normalized for 20_01_2024 is tensor([[0.4152]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 20_01_2024 is -0.3092817326387455
# Predicted rain normalized for 21_01_2024 is tensor([[0.4149]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 21_01_2024 is -0.32236044818546217
# Predicted rain normalized for 22_01_2024 is tensor([[0.4152]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 22_01_2024 is -0.32236044818546217
# Predicted rain normalized for 23_01_2024 is tensor([[0.4150]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 23_01_2024 is -0.32236044818546217
# Predicted rain normalized for 24_01_2024 is tensor([[0.4164]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 24_01_2024 is -0.32236044818546217
# Predicted rain normalized for 25_01_2024 is tensor([[0.4161]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 25_01_2024 is -0.32236044818546217
# Predicted rain normalized for 26_01_2024 is tensor([[0.4147]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 26_01_2024 is -0.32236044818546217
# Predicted rain normalized for 27_01_2024 is tensor([[0.4151]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 27_01_2024 is -0.32236044818546217
# Predicted rain normalized for 28_01_2024 is tensor([[0.4145]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 28_01_2024 is -0.3092817326387455
# Predicted rain normalized for 29_01_2024 is tensor([[0.4148]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 29_01_2024 is -0.32236044818546217
# Predicted rain normalized for 30_01_2024 is tensor([[0.4146]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 30_01_2024 is -0.32236044818546217
# Predicted rain normalized for 31_01_2024 is tensor([[0.4155]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 31_01_2024 is -0.32236044818546217
# Predicted rain normalized for 01_02_2024 is tensor([[0.4156]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 01_02_2024 is -0.32236044818546217
# Predicted rain normalized for 02_02_2024 is tensor([[0.4141]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 02_02_2024 is -0.32236044818546217
# Predicted rain normalized for 03_02_2024 is tensor([[0.4158]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 03_02_2024 is -0.32236044818546217
# Predicted rain normalized for 04_02_2024 is tensor([[0.4151]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 04_02_2024 is -0.32236044818546217
# Predicted rain normalized for 05_02_2024 is tensor([[0.4159]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 05_02_2024 is -0.32236044818546217
# Predicted rain normalized for 06_02_2024 is tensor([[0.4160]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 06_02_2024 is -0.32236044818546217
# Predicted rain normalized for 07_02_2024 is tensor([[0.4163]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 07_02_2024 is -0.32236044818546217
# Predicted rain normalized for 08_02_2024 is tensor([[0.4163]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 08_02_2024 is -0.32236044818546217
# Predicted rain normalized for 09_02_2024 is tensor([[0.4163]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 09_02_2024 is -0.02154999061097813
# Predicted rain normalized for 10_02_2024 is tensor([[0.4164]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 10_02_2024 is 1.1293769775000913
# Predicted rain normalized for 11_02_2024 is tensor([[0.4165]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 11_02_2024 is 1.0639833997665076
# Predicted rain normalized for 12_02_2024 is tensor([[0.4164]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 12_02_2024 is 0.05692230266932207
# Predicted rain normalized for 13_02_2024 is tensor([[0.4139]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 13_02_2024 is -0.32236044818546217
# Predicted rain normalized for 14_02_2024 is tensor([[0.4141]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 14_02_2024 is -0.32236044818546217
# Predicted rain normalized for 15_02_2024 is tensor([[0.4154]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 15_02_2024 is -0.32236044818546217
# Predicted rain normalized for 16_02_2024 is tensor([[0.4156]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 16_02_2024 is -0.29620301709202873
# Predicted rain normalized for 17_02_2024 is tensor([[0.4151]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 17_02_2024 is -0.32236044818546217
# Predicted rain normalized for 18_02_2024 is tensor([[0.4160]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 18_02_2024 is -0.3092817326387455
# Predicted rain normalized for 19_02_2024 is tensor([[0.4162]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 19_02_2024 is -0.24388815490516197
# Predicted rain normalized for 20_02_2024 is tensor([[0.4155]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 20_02_2024 is -0.32236044818546217
# Predicted rain normalized for 21_02_2024 is tensor([[0.4146]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 21_02_2024 is -0.32236044818546217
# Predicted rain normalized for 22_02_2024 is tensor([[0.4167]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 22_02_2024 is -0.047707421704411494
# Predicted rain normalized for 23_02_2024 is tensor([[0.4164]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 23_02_2024 is 1.8748637636629433
# Predicted rain normalized for 24_02_2024 is tensor([[0.4168]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 24_02_2024 is -0.32236044818546217
# Predicted rain normalized for 25_02_2024 is tensor([[0.4149]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 25_02_2024 is -0.2700455859985954
# Predicted rain normalized for 26_02_2024 is tensor([[0.4170]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 26_02_2024 is -0.32236044818546217
# Predicted rain normalized for 27_02_2024 is tensor([[0.4170]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 27_02_2024 is 0.05692230266932207
# Predicted rain normalized for 28_02_2024 is tensor([[0.4170]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 28_02_2024 is -0.2831243015453121
# Predicted rain normalized for 29_02_2024 is tensor([[0.4170]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 29_02_2024 is -0.32236044818546217
# Predicted rain normalized for 01_03_2024 is tensor([[0.4160]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 01_03_2024 is -0.02154999061097813
# Predicted rain normalized for 02_03_2024 is tensor([[0.4159]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 02_03_2024 is 0.7370155110985903
# Predicted rain normalized for 03_03_2024 is tensor([[0.4160]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 03_03_2024 is -0.2831243015453121
# Predicted rain normalized for 04_03_2024 is tensor([[0.4162]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 04_03_2024 is -0.29620301709202873
# Predicted rain normalized for 05_03_2024 is tensor([[0.4145]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 05_03_2024 is -0.32236044818546217
# Predicted rain normalized for 06_03_2024 is tensor([[0.4161]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 06_03_2024 is 0.4362050535241063
# Predicted rain normalized for 07_03_2024 is tensor([[0.4136]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 07_03_2024 is -0.32236044818546217
# Predicted rain normalized for 08_03_2024 is tensor([[0.4163]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 08_03_2024 is -0.2700455859985954
# Predicted rain normalized for 09_03_2024 is tensor([[0.4162]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 09_03_2024 is 1.0901408308599414
# Predicted rain normalized for 10_03_2024 is tensor([[0.4163]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 10_03_2024 is 1.0901408308599414
# Predicted rain normalized for 11_03_2024 is tensor([[0.4167]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 11_03_2024 is -0.3092817326387455
# Predicted rain normalized for 12_03_2024 is tensor([[0.4149]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 12_03_2024 is -0.32236044818546217
# Predicted rain normalized for 13_03_2024 is tensor([[0.4144]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 13_03_2024 is -0.32236044818546217
# Predicted rain normalized for 14_03_2024 is tensor([[0.4152]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 14_03_2024 is -0.32236044818546217
# Predicted rain normalized for 15_03_2024 is tensor([[0.4166]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 15_03_2024 is -0.32236044818546217
# Predicted rain normalized for 16_03_2024 is tensor([[0.4161]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 16_03_2024 is -0.32236044818546217
# Predicted rain normalized for 17_03_2024 is tensor([[0.4152]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 17_03_2024 is -0.32236044818546217
# Predicted rain normalized for 18_03_2024 is tensor([[0.4167]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 18_03_2024 is -0.15233714607814508
# Predicted rain normalized for 19_03_2024 is tensor([[0.4145]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 19_03_2024 is -0.32236044818546217
# Predicted rain normalized for 20_03_2024 is tensor([[0.4141]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 20_03_2024 is -0.32236044818546217
# Predicted rain normalized for 21_03_2024 is tensor([[0.4165]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 21_03_2024 is -0.3092817326387455
# Predicted rain normalized for 22_03_2024 is tensor([[0.4150]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 22_03_2024 is -0.32236044818546217
# Predicted rain normalized for 23_03_2024 is tensor([[0.4152]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 23_03_2024 is 0.21386688922992242
# Predicted rain normalized for 24_03_2024 is tensor([[0.4144]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 24_03_2024 is 0.6323857867248568
# Predicted rain normalized for 25_03_2024 is tensor([[0.4156]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 25_03_2024 is -0.32236044818546217
# Predicted rain normalized for 26_03_2024 is tensor([[0.4172]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 26_03_2024 is 0.030764871575888707
# Predicted rain normalized for 27_03_2024 is tensor([[0.4170]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 27_03_2024 is 1.7702340392892097
# Predicted rain normalized for 28_03_2024 is tensor([[0.4168]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 28_03_2024 is 2.9342397229469954
# Predicted rain normalized for 29_03_2024 is tensor([[0.4171]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 29_03_2024 is -0.32236044818546217
# Predicted rain normalized for 30_03_2024 is tensor([[0.4162]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 30_03_2024 is -0.32236044818546217
# Predicted rain normalized for 31_03_2024 is tensor([[0.4173]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 31_03_2024 is 0.030764871575888707
# Predicted rain normalized for 01_04_2024 is tensor([[0.4157]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 01_04_2024 is 3.4835457759090973
# Predicted rain normalized for 02_04_2024 is tensor([[0.4158]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 02_04_2024 is -0.32236044818546217
# Predicted rain normalized for 03_04_2024 is tensor([[0.4161]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 03_04_2024 is -0.32236044818546217
# Predicted rain normalized for 04_04_2024 is tensor([[0.4146]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 04_04_2024 is -0.32236044818546217
# Predicted rain normalized for 05_04_2024 is tensor([[0.4159]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 05_04_2024 is -0.32236044818546217
# Predicted rain normalized for 06_04_2024 is tensor([[0.4144]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 06_04_2024 is -0.32236044818546217
# Predicted rain normalized for 07_04_2024 is tensor([[0.4141]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 07_04_2024 is -0.32236044818546217
# Predicted rain normalized for 08_04_2024 is tensor([[0.4141]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 08_04_2024 is -0.32236044818546217
# Predicted rain normalized for 09_04_2024 is tensor([[0.4154]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 09_04_2024 is -0.32236044818546217
# Predicted rain normalized for 10_04_2024 is tensor([[0.4161]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 10_04_2024 is -0.32236044818546217
# Predicted rain normalized for 11_04_2024 is tensor([[0.4144]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 11_04_2024 is -0.32236044818546217
# Predicted rain normalized for 12_04_2024 is tensor([[0.4141]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 12_04_2024 is -0.32236044818546217
# Predicted rain normalized for 13_04_2024 is tensor([[0.4143]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 13_04_2024 is -0.32236044818546217
# Predicted rain normalized for 14_04_2024 is tensor([[0.4145]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 14_04_2024 is -0.32236044818546217
# Predicted rain normalized for 15_04_2024 is tensor([[0.4150]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 15_04_2024 is -0.32236044818546217
# Predicted rain normalized for 16_04_2024 is tensor([[0.4164]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 16_04_2024 is 0.4362050535241063
# Predicted rain normalized for 17_04_2024 is tensor([[0.4151]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 17_04_2024 is -0.3092817326387455
# Predicted rain normalized for 18_04_2024 is tensor([[0.4167]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 18_04_2024 is -0.32236044818546217
# Predicted rain normalized for 19_04_2024 is tensor([[0.4146]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 19_04_2024 is -0.32236044818546217
# Predicted rain normalized for 20_04_2024 is tensor([[0.4167]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 20_04_2024 is -0.3092817326387455
# Predicted rain normalized for 21_04_2024 is tensor([[0.4147]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 21_04_2024 is -0.2831243015453121
# Predicted rain normalized for 22_04_2024 is tensor([[0.4164]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 22_04_2024 is 1.0770621153132245
# Predicted rain normalized for 23_04_2024 is tensor([[0.4169]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 23_04_2024 is 0.10923716485618885
# Predicted rain normalized for 24_04_2024 is tensor([[0.4171]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 24_04_2024 is 0.4362050535241063
# Predicted rain normalized for 25_04_2024 is tensor([[0.4169]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 25_04_2024 is -0.11310099943799498
# Predicted rain normalized for 26_04_2024 is tensor([[0.4165]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 26_04_2024 is -0.32236044818546217
# Predicted rain normalized for 27_04_2024 is tensor([[0.4169]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 27_04_2024 is -0.32236044818546217
# Predicted rain normalized for 28_04_2024 is tensor([[0.4161]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 28_04_2024 is -0.32236044818546217
# Predicted rain normalized for 29_04_2024 is tensor([[0.4150]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 29_04_2024 is -0.32236044818546217
# Predicted rain normalized for 30_04_2024 is tensor([[0.4152]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 30_04_2024 is -0.32236044818546217
# Predicted rain normalized for 01_05_2024 is tensor([[0.4147]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 01_05_2024 is 0.5669922089912733
# Predicted rain normalized for 02_05_2024 is tensor([[0.4158]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 02_05_2024 is 1.364793857340992
# Predicted rain normalized for 03_05_2024 is tensor([[0.4162]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 03_05_2024 is -0.07386485279784491
# Predicted rain normalized for 04_05_2024 is tensor([[0.4161]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 04_05_2024 is -0.32236044818546217
# Predicted rain normalized for 05_05_2024 is tensor([[0.4148]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 05_05_2024 is -0.32236044818546217
# Predicted rain normalized for 06_05_2024 is tensor([[0.4160]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 06_05_2024 is -0.32236044818546217
# Predicted rain normalized for 07_05_2024 is tensor([[0.4161]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 07_05_2024 is 2.489563394358628
# Predicted rain normalized for 08_05_2024 is tensor([[0.4147]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 08_05_2024 is -0.25696687045187866
# Predicted rain normalized for 09_05_2024 is tensor([[0.4143]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 09_05_2024 is -0.3092817326387455
# Predicted rain normalized for 10_05_2024 is tensor([[0.4141]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 10_05_2024 is -0.32236044818546217
# Predicted rain normalized for 11_05_2024 is tensor([[0.4145]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 11_05_2024 is -0.32236044818546217
# Predicted rain normalized for 12_05_2024 is tensor([[0.4147]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 12_05_2024 is -0.32236044818546217
# Predicted rain normalized for 13_05_2024 is tensor([[0.4167]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 13_05_2024 is -0.3092817326387455
# Predicted rain normalized for 14_05_2024 is tensor([[0.4170]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 14_05_2024 is -0.3092817326387455
# Predicted rain normalized for 15_05_2024 is tensor([[0.4167]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 15_05_2024 is 0.39696890688395625
# Predicted rain normalized for 16_05_2024 is tensor([[0.4168]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 16_05_2024 is 0.8416452354723241
# Predicted rain normalized for 17_05_2024 is tensor([[0.4162]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 17_05_2024 is -0.32236044818546217
# Predicted rain normalized for 18_05_2024 is tensor([[0.4150]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 18_05_2024 is -0.32236044818546217
# Predicted rain normalized for 19_05_2024 is tensor([[0.4162]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 19_05_2024 is -0.32236044818546217
# Predicted rain normalized for 20_05_2024 is tensor([[0.4168]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 20_05_2024 is -0.2700455859985954
# Predicted rain normalized for 21_05_2024 is tensor([[0.4170]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 21_05_2024 is 1.2078492707803916
# Predicted rain normalized for 22_05_2024 is tensor([[0.4177]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 22_05_2024 is -0.25696687045187866
# Predicted rain normalized for 23_05_2024 is tensor([[0.4153]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 23_05_2024 is -0.2831243015453121
# Predicted rain normalized for 24_05_2024 is tensor([[0.4145]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 24_05_2024 is -0.2700455859985954
# Predicted rain normalized for 25_05_2024 is tensor([[0.4157]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 25_05_2024 is -0.32236044818546217
# Predicted rain normalized for 26_05_2024 is tensor([[0.4152]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 26_05_2024 is -0.3092817326387455
# Predicted rain normalized for 27_05_2024 is tensor([[0.4160]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 27_05_2024 is -0.32236044818546217
# Predicted rain normalized for 28_05_2024 is tensor([[0.4154]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 28_05_2024 is -0.11310099943799498
# Predicted rain normalized for 29_05_2024 is tensor([[0.4167]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 29_05_2024 is -0.32236044818546217
# Predicted rain normalized for 30_05_2024 is tensor([[0.4168]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 30_05_2024 is 3.143499171694463
# Predicted rain normalized for 31_05_2024 is tensor([[0.4166]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 31_05_2024 is 4.556000450739866
# Predicted rain normalized for 01_06_2024 is tensor([[0.4159]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 01_06_2024 is -0.24388815490516197
# Predicted rain normalized for 02_06_2024 is tensor([[0.4140]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 02_06_2024 is 0.39696890688395625
# Predicted rain normalized for 03_06_2024 is tensor([[0.4160]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 03_06_2024 is -0.32236044818546217
# Predicted rain normalized for 04_06_2024 is tensor([[0.4153]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 04_06_2024 is -0.32236044818546217
# Predicted rain normalized for 05_06_2024 is tensor([[0.4153]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 05_06_2024 is -0.32236044818546217
# Predicted rain normalized for 06_06_2024 is tensor([[0.4143]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 06_06_2024 is -0.32236044818546217
# Predicted rain normalized for 07_06_2024 is tensor([[0.4146]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 07_06_2024 is -0.32236044818546217
# Predicted rain normalized for 08_06_2024 is tensor([[0.4166]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 08_06_2024 is -0.32236044818546217
# Predicted rain normalized for 09_06_2024 is tensor([[0.4165]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 09_06_2024 is -0.32236044818546217
# Predicted rain normalized for 10_06_2024 is tensor([[0.4146]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 10_06_2024 is 5.9815804453319865
# Predicted rain normalized for 11_06_2024 is tensor([[0.4162]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 11_06_2024 is 4.085166691058066
# Predicted rain normalized for 12_06_2024 is tensor([[0.4143]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 12_06_2024 is -0.3092817326387455
# Predicted rain normalized for 13_06_2024 is tensor([[0.4165]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 13_06_2024 is 0.17463074258977235
# Predicted rain normalized for 14_06_2024 is tensor([[0.4157]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Real rain normalized  for 14_06_2024 is -0.32236044818546217
